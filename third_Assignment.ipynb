# %% [markdown]
# # Q1. Build a simple webpage that displays text as shown in the below image?
# - **Ans:-**
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#
#     <p><b>This text will be bolded.</b></p>
#     <p><i>This text will be italic.</i></p>
#     <p><u>This text will be underlined</u>.</p>
#     <mark>This text will be highlighted</mark>
#     <p>This is normal text <sup>this will be super scripted</sup>This is normal again</p>
#     <p>This is normal text <sub>this text will be subscripted</sub></p>
#     <p>This text will be bolded.</p>
#     <p><strike>This text will be bolded.</strike></p>
#     <p>Normal Text <small>small text</small> </p>
#
#
#
#
# </body>
# </html>

# %% [markdown]
# # Q2. Build a simple webpage that helps users navigate different web development-related websites. Note: On clicking the hyperlink the web pages should open in a new tab. Below is a reference image.
# - Ans:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <div style="border:1px solid black ;">
#         <h1>Navigate Me :</h1>
#         <p>Take me to <a href="https://pwskills.com/checkout/?course_id=67c91ec528d08bcf1ea3c0a7&source=description_page&plan_name=Premium" target="_blank">PW Skills</a> to buy a course.</p>
#         <p> Take me to <a href="https://pwskills.com/course/full-stack-web-development-course/?position=checkout_page" target="_blank">MDN docs</a>to know more about Web Development.</p>
#         <p>Take me to <a href="https://pwskills.com" target="_blank">PW Skills Lab</a> to practice live coding.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# # Q 3. Build a simple blog web page with 3 pages home, web development, and web design. Each page must contain hyperlinks to other pages in the top, a heading of the page topic and a paragraph of information. For the home page you can add some information about yourself?
# **First-Page**
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Home - Simple Blog</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 0;
#             background-color: #f4f4f4;
#         }
#         header {
#             background-color: #333;
#             color: white;
#             padding: 10px;
#             text-align: center;
#         }
#         nav a {
#             margin: 0 15px;
#             color: white;
#             text-decoration: none;
#         }
#         section {
#             padding: 20px;
#         }
#         footer {
#             text-align: center;
#             background-color: #333;
#             color: white;
#             padding: 10px;
#             position: fixed;
#             width: 100%;
#             bottom: 0;
#         }
#     </style>
# </head>
# <body>
#     <header>
#         <h1>Simple Blog</h1>
#         <nav>
#             <a href="index.html">Home</a>
#             <a href="web-development.html">Web Development</a>
#             <a href="web-design.html">Web Design</a>
#         </nav>
#     </header>
#        <div>
#         <u><h1>Nihal Gupta</h1></u>
#         <p><b>Phone :-</b>(+91) 9559145614</p>
#         <p><b>Email Address :-</b> <a href="" target="_blank">guptasnihal72@gmail.com</a></p>
#         <p><b>Address :-</b> Mungraw Handia Prayagraj Uttar Pradesh 221503</p><hr>
#        </div>
#        <div>
#         <p>Motivated and detail-oriented Cyber Security Researcher with strong knowledge of Networking &
#             Cybersecurity Concepts. Self-motivated, and a keep learner with a deep interest in researching about
#             vulnerabilities and simulating them in own environment.</p>
#        </div>
#        <div>
#         <p><b>Qualifications :-</b></p>
#         <ul>
#             <li>Completed national Inter college 10<sup>th</sup> From UP Board 2018</li>
#             <li>Completed National Inter College 12<sup>th</sup> from Up Board 2020</li>
#             <li>Pursuing <b>BCA</b>Final year <b>Himalayan garhwal University (uttarakhand)</b></li>
#         </ul>
#         <p><b>Professional Qualification :-</b></p>
#         <ul>
#             <li>Complete Advance Diploma in Computer Applications <b>(ADCA)</b> & Advance Diploma in Information Technology <b>(ADIT)</b> from <b>M.Tech Computer Education Institute Handia Prayagraj</b> Uttar Pradesh India.</li>
#             <li>Complete Diploma in <b>Cyber Security</b> from <b>NetTechIndia Institute</b> Mumbai India. </li>
#         </ul>
#        </div>
#        <div>
#         <p><b>Skills: Web Application Penetration testing | Network Penetration Testing | Penetration Testing | VAPT | Network Security | application Security</b></p>
#         <ul>
#             <li><b>OS -</b> Windows, Kali Linux</li>
#             <li><b>Tools - </b> Burpsuite, Nessus, Nmap, Hydra, Wireshark, Disbuster, Hashcat, SqlMap, Metasploit, Nikto John the Ripper</li>
#             <li> <b>Software Used - </b> Ms office, Photoshop, CoralDraw, etc..</li>
#         </ul>
#         <p><b>Declaration :-</b></p>
#         <p>I Hereby declare the above written particulars are true to the best of my knowledge and belief.</p>
#        </div>
#
#     </body>
#     </html>
# </body>
# </html>
#
# **second-page**
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Web Development - Simple Blog</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 0;
#             background-color: #f4f4f4;
#         }
#         header {
#             background-color: #333;
#             color: white;
#             padding: 10px;
#             text-align: center;
#         }
#         nav a {
#             margin: 0 15px;
#             color: white;
#             text-decoration: none;
#         }
#         section {
#             padding: 20px;
#         }
#         footer {
#             text-align: center;
#             background-color: #333;
#             color: white;
#             padding: 10px;
#             position: fixed;
#             width: 100%;
#             bottom: 0;
#         }
#     </style>
# </head>
# <body>
#     <header>
#         <h1>Simple Blog</h1>
#         <nav>
#             <a href="index.html">Home</a>
#             <a href="web-development.html">Web Development</a>
#             <a href="web-design.html">Web Design</a>
#         </nav>
#     </header>
#
#     <section>
#         <h2>Web Development</h2>
#         <p>Web development involves creating and maintaining websites. It encompasses both the front-end (user interface) and back-end (server-side logic) of a website. The tools and technologies used in web development include HTML, CSS, JavaScript, and server-side languages like Node.js, Python, and PHP.</p>
#     </section>
#
#     <footer>
#         <p>&copy; 2025 Simple Blog</p>
#     </footer>
# </body>
# </html>
# **third-page**
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Web Design - Simple Blog</title>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#             margin: 0;
#             padding: 0;
#             background-color: #f4f4f4;
#         }
#         header {
#             background-color: #333;
#             color: white;
#             padding: 10px;
#             text-align: center;
#         }
#         nav a {
#             margin: 0 15px;
#             color: white;
#             text-decoration: none;
#         }
#         section {
#             padding: 20px;
#         }
#         footer {
#             text-align: center;
#             background-color: #333;
#             color: white;
#             padding: 10px;
#             position: fixed;
#             width: 100%;
#             bottom: 0;
#         }
#     </style>
# </head>
# <body>
#     <header>
#         <h1>Simple Blog</h1>
#         <nav>
#             <a href="index.html">Home</a>
#             <a href="web-development.html">Web Development</a>
#             <a href="web-design.html">Web Design</a>
#         </nav>
#     </header>
#
#     <section>
#         <h2>Web Design</h2>
#         <p>Web design focuses on the visual aspects of a website, such as layout, color schemes, typography, and user experience. A good web design enhances user interaction with the website and improves accessibility across different devices and screen sizes.</p>
#     </section>
#
#     <footer>
#         <p>&copy; 2025 Simple Blog</p>
#     </footer>
# </body>
# </html>

# %% [markdown]
# # Q4.Create an ordered list of HTML tags. Each list item must include the tag name and some information about the tag?
# - Ans
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#        <div>
#         <p>html tags: The root element of an HTML document. It contains all other elements.</p>
#         <p>head tags:ins meta-information about the HTML document, such as its title and links to stylesheets.</p>
#         <p>title tags:the title of the HTML document, which is displayed in the browser's title bar or tab.</p>
#         <p>body tags:ins the content of the HTML document, such as text, images, and other media.</p>
#          <p>h1 to h6 tags: Header tags used to define headings, with h1 being the highest level and h6 the lowest.</p>
#         <p>p tags: Defines a paragraph of text.</p>
#         <p>a  tags:Defines a hyperlink, which is used to link from one page to another.</p>
#         <p>img tags:is an image in the HTML document.</p>
#         <p>ul tags:es an unordered list, typically rendered as a bulleted list.</p>
#         <p>ol tags:es an ordered list, typically rendered as a numbered list.</p>
#         <p>li tags:es a list item, which can be used within ul or ol  elements.</p>
#         <p>div tags: Defines a division or section in an HTML document, often used as a container for other elements.</p>
#         <p>span tags: Defines a section of text within a document, often used for styling purposes.</p>
#         <p>form tags:es an HTML form for user input.</p>
#         <p>input tags:es an input field within a form, such as a text box or checkbox</p>
#
# </body>
# </html>

# %% [markdown]
# # Q5. Create a description list of full stack web development tech stack, using the dl tag. Each term should be a tech stack name and each description should be a brief explanation of what the tech stack is used for ?
# - Ans
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <dl>
#         <dt>HTML (HyperText Markup Language)</dt>
#         <dd>The standard markup language for creating web pages, defining the structure and content of a webpage.</dd>
#
#         <dt>CSS (Cascading Style Sheets)</dt>
#         <dd>A style sheet language used for describing the presentation of a document written in HTML or XML, controlling the layout and visual appearance of web pages.</dd>
#
#         <dt>JavaScript</dt>
#         <dd>A programming language that enables interactive web pages, handling client-side logic, user interactions, and dynamic content manipulation.</dd>
#
#         <dt>React</dt>
#         <dd>A JavaScript library for building user interfaces, especially for single-page applications where speed is crucial. It allows developers to create reusable UI components.</dd>
#
#         <dt>Angular</dt>
#         <dd>A comprehensive JavaScript-based framework for building complex web applications, providing a robust architecture for front-end development.</dd>
#
#         <dt>Vue.js</dt>
#         <dd>A progressive JavaScript framework for building user interfaces, known for its simplicity and flexibility, making it easy to integrate into existing projects.</dd>
#
#         <dt>Node.js</dt>
#         <dd>A JavaScript runtime built on Chrome's V8 JavaScript engine, enabling server-side JavaScript development and creating scalable network applications.</dd>
#
#         <dt>Express.js</dt>
#         <dd>A fast, unopinionated, minimalist web framework for Node.js, providing a set of features for web and mobile applications.</dd>
#
#         <dt>Python (with Flask/Django)</dt>
#         <dd>A versatile programming language used for back-end development, often paired with Flask (a microframework) or Django (a full-featured framework) for building web applications.</dd>
#
#         <dt>Ruby on Rails</dt>
#         <dd>A server-side web application framework written in Ruby, following the convention over configuration paradigm, making it efficient for rapid development.</dd>
#
#         <dt>PHP (with Laravel/Symfony)</dt>
#         <dd>A server-side scripting language used for web development, often paired with Laravel (a modern PHP framework) or Symfony (a reusable PHP component library) for building dynamic websites.</dd>
#
#         <dt>SQL (Structured Query Language)</dt>
#         <dd>A domain-specific language used in programming and designed for managing data held in a relational database management system (RDBMS).</dd>
#
#         <dt>MySQL</dt>
#         <dd>A popular open-source relational database management system (RDBMS) widely used for web applications.</dd>
#
#         <dt>PostgreSQL</dt>
#         <dd>A powerful, open-source relational database system that uses and extends the SQL language combined with many features that safely store and scale the most complicated data workloads.</dd>
#
#           <dt>MongoDB</dt>
#           <dd>A cross-platform document-oriented database program. Classified as a NoSQL database program, MongoDB uses JSON-like documents with optional schemas.</dd>
#
#         <dt>Git</dt>
#         <dd>A distributed version-control system for tracking changes in source code during software development, enabling collaboration and version management.</dd>
#
#           <dt>REST APIs (Representational State Transfer)</dt>
#           <dd>An architectural style for designing networked applications. REST relies on a stateless, client-server, cacheable communications protocol -- and in virtually all cases, the HTTP protocol is used.</dd>
#       </dl>
# </body>
# </html>

# %% [markdown]
# #Q6. Create an ordered list of the full stack web development tech stack HTML, CSS, and JS. For each tech stack, create a table that lists the tech stack name, its primary use cases, and some key features or benefits. Below is a reference image?
# - Ans: -
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <div>
#         <h1>1. HTML</h1>
#         <table border="5">
#             <tr>
#                 <th>Primary Use Cases</th>
#                 <th>Key Features/Benefits</th>
#             </tr>
#             <tr>
#                 <td>Building the structure of web pages</td>
#                 <td>
#                     <ul type="circle">
#                         <li>Simple and east to learn</li>
#                         <li>Compatible with all web browsers</li>
#                         <li>Allows for semantic markup</li>
#                     </ul>
#                 </td>
#             </tr>
#         </table>
#     </div>
#     <div>
#         <h1>2. CSS</h1>
#         <table border="5">
#             <tr>
#                 <th>Primary Use Case</th>
#                 <th>Key features/Benefits</th>
#             </tr>
#             <tr>
#                 <td>Styling and layout of web pages</td>
#                 <td>
#                     <ul type="circle">
#                         <li>Allows for separation of content and presentation</li>
#                         <li>Enables responsive design</li>
#                         <li>Offers a wide range of styling options</li>
#                     </ul>
#                 </td>
#             </tr>
#         </table>
#     </div>
#
# </body>
# </html>

# %% [markdown]
# #Q7. Build a complex nested list structure representing a multi-level table of contents. Use unordered lists (ul) and list items (li) with inline-block styling to create a structured layout. Apply formatting tags to enhance the presentation of list items?
# - Ans:-
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <div style="border: 3px solid black; width: 400px;">
#         <h1>Table of Contents</h1>
#     <ul>
#         <li><a href="">Part 1: Introduction</a></li>
#         <li><a href="">Part 2: Getting Started</a></li>
#         <ul>
#             <li><a href="">2.1 Installing the software</a></li>
#             <li><a href="">2.2 Creating a New Project</a></li>
#             <ul>
#                 <li><a href="">2.2.1 Project Templates</a></li>
#                 <li><a href="">2.2.2 Customizing Setting</a></li>
#             </ul>
#             <li><a href="">2.3 Exploring the Interface</a></li>
#             <ul>
#                 <li><a href="">2.3.1 Toolbar Features</a></li>
#                 <li><a href="">2.3.2 Panel Layout</a></li>
#                 <ul>
#                     <li><a href="">2.3.2.1 Docking Panels</a></li>
#                     <li><a href="">2.3.2.2 Tabbed Interface</a></li>
#                 </ul>
#             </ul>
#         </ul>
#         <li><a href="">part 3 : Advanced Topics</a></li>
#         <ul>
#             <li><a href="">3.1 Working with plugins</a></li>
#             <ul>
#                 <li><a href="">3.1.1 Installing Plugins</a></li>
#                 <li><a href="">3.1.2 Plugin Configurations</a></li>
#             </ul>
#             <li><a href="">3.2 Customizing the UI</a></li>
#             <ul>
#                 <li><a href="">3.2.1 Changing Themes</a></li>
#                 <li><a href="">3.2.2 Configuring Shortcuts</a></li>
#             </ul>
#             <li><a href="">3.3 Optimizing Performance</a></li>
#             <ul>
#                 <li><a href="">3.3.1 Caching Strategies</a></li>
#                 <li><a href="">3.3.2 Resource Minification</a></li>
#             </ul>
#         </ul>
#         <li><a href="">Part4 : Conclusion</a></li>
#     </ul>
#     </div>
#
# </body>
# </html>

# %% [markdown]
# # Q 8.Create a table to display a conference schedule. Each row corresponds to a time slot, and each column corresponds to a room. Some time slots might have multiple sessions running simultaneously in different rooms. Utilize rowspan and colspan attributes as necessary to accommodate this complex schedule.(use table attribute “cellpadding”  to give extra padding in each table cell )?
# - Ans
#
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Document</title>
# </head>
# <body>
#     <h1>Conference Schedule</h1>
#    <div style=" text-align: center;">
#     <table border="1" width="700px" height="300">
#         <tr >
#             <th>Time</th>
#             <th>Room 1</th>
#             <th>Room 2</th>
#             <th>Room 3</th>
#             <th>Room 4</th>
#         </tr>
#         <tr>
#             <td rowspan="3">9:00 AM - 10:00 AM</td>
#             <td rowspan="2">Keynote</td>
#             <td> Session A</td>
#             <td>Seccion B</td>
#             <td rowspan="3">Session C</td>
#         </tr>
#         <tr>
#             <td>Session D</td>
#             <td>Session E</td>
#          </tr>
#         <tr>
#             <td colspan="2">10:30 AM - 11:30 AM</td>
#             <td>Session F</td>
#         </tr>
#         <tr>
#             <td>12:00 PM - 1:00 PM</td>
#             <td colspan="4">Lunch Break</td>
#         </tr>
#         <tr>
#             <td rowspan="2">1:00 PM - 2:00 PM</td>
#             <td>Session G</td>
#             <td rowspan="2">Session H</td>
#             <td>Session I</td>
#             <td>Session J</td>
#         </tr>
#         <tr>
#             <td>Session K</td>
#             <td>Session L</td>
#             <td>Session M</td>
#         </tr>
#     </table>
#    </div>
#
# </body>
# </html>
